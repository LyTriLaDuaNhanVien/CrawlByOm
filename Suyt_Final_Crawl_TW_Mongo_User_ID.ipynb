# %%
import pandas as pd
import tweepy
import pymongo

# %%
import pymongo
CONNECTION_STRING='Your Connect String'
client = pymongo.MongoClient(CONNECTION_STRING)
db= client["demotw"]
print("Input: ")
id=input()
om=input()
# Out:
# Input:
# WasteTodayMag
# 2

# %%
# Key API Twitter
# %run ./key.ipynb

# %%
collection= db['demo']

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token_key,access_token_secret)
api=tweepy.API(auth)
try:
    redirect_url = auth.get_authorization_url()
except tweepy.TweepError:
    print('Error! Failed to get request token.')

# %%
cursor=tweepy.Cursor(api.user_timeline,id=id, tweet_mode="extended").items(5000)
for i in cursor:
    post={'id':i.id_str,'Titlle':'null','Content':i.full_text,'CreatedDate':i.created_at,'Location':'null','Link':'https://twitter.com/'+id+'/status/'+i.id_str,'TypeID':om,"TypeIDText":abc,'Enviroment':"2"}
    collection.insert_one(post)
# Out:
# Unexpected parameter: id
# Unexpected parameter: id
# Unexpected parameter: id
# Unexpected parameter: id
# Unexpected parameter: id
# Unexpected parameter: id
# Unexpected parameter: id
# Unexpected parameter: id
# Unexpected parameter: id
# Unexpected parameter: id
# Unexpected parameter: id
# Unexpected parameter: id
# Unexpected parameter: id
# Unexpected parameter: id
# Unexpected parameter: id
# Unexpected parameter: id
# Unexpected parameter: id
# Unexpected parameter: id
# Unexpected parameter: id
# Unexpected parameter: id
# Unexpected parameter: id
# Unexpected parameter: id
# Unexpected parameter: id
# Unexpected parameter: id
# Unexpected parameter: id
# Unexpected parameter: id
# Unexpected parameter: id
# Unexpected parameter: id
# Unexpected parameter: id
# Unexpected parameter: id
# Unexpected parameter: id
# Unexpected parameter: id
# Unexpected parameter: id
# Unexpected parameter: id
# Unexpected parameter: id
# Unexpected parameter: id
# Unexpected parameter: id
# ...
